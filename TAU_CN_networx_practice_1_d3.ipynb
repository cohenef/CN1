# %% [markdown]
# <a href="https://colab.research.google.com/github/cohenef/CN1/blob/main/TAU_CN_networx_practice_1_d3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NetworkX practice 1

# %%
import networkx as nx # the main libary we will use
from networkx.algorithms import bipartite
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
G = nx.Graph()
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_node('B')
G.add_node('Danny')
G.add_edge(1,2)
G.add_edge('B',3)
G.add_edge('B','Danny')

# %%
G.number_of_nodes()
# Out:
# 5

# %%
G.number_of_edges()
# Out:
# 3

# %%
G.edges()
# Out:
# EdgeView([(1, 2), (3, 'B'), ('B', 'Danny')])

# %%
A = nx.adjacency_matrix(G)
print(A)
# Out:
#   (0, 1)	1
#   (1, 0)	1
#   (2, 3)	1
#   (3, 2)	1
#   (3, 4)	1
#   (4, 3)	1

# %%
A = nx.to_numpy_matrix(G)
plt.matshow(A)

# %%
G.nodes()
# Out:
# NodeView((1, 2, 3, 'B', 'Danny'))

# %%
N = 100
p = 0.1
G = nx.gnp_random_graph(N,p)

# %%
degree_hist = nx.degree_histogram(G)
print(degree_hist)
# Out:
# [0, 0, 0, 0, 2, 1, 10, 10, 7, 12, 13, 12, 11, 12, 3, 1, 0, 6]

# %%
degree_prob = np.array(degree_hist)/G.number_of_nodes()
plt.bar(np.arange(len(degree_hist)),degree_prob)
# Out:
# <BarContainer object of 18 artists>

# %%
print(nx.average_clustering(G))
# Out:
# 0.09507529888412235

# %%
# !git clone https://github.com/cohenef/CN1
# Out:
# Cloning into 'CN1'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 30 (delta 7), reused 11 (delta 1), pack-reused 0
# Unpacking objects: 100% (30/30), done.

# %%
# !git clone https://github.com/Omer80/DatasetsComplexNetworksCourse
# Out:
# Cloning into 'DatasetsComplexNetworksCourse'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %%
G = nx.read_adjlist("/content/DatasetsComplexNetworksCourse/graph_01.txt",create_using=nx.Graph,nodetype=str)
nx.draw(G,with_labels=True)

# %%
G = nx.read_adjlist("/content/CN1/opencell-protein-interactions_inter_stoich.csv",create_using=nx.Graph,nodetype=str)
nx.draw(G,with_labels=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f647dd183d60> in <module>()
#       1 G = nx.read_adjlist("/content/CN1/opencell-protein-interactions_inter_stoich.csv",create_using=nx.Graph,nodetype=str)
# ----> 2 nx.draw(G,with_labels=False)
#
# /usr/local/lib/python3.7/dist-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     119         kwds["with_labels"] = "labels" in kwds
#     120
# --> 121     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122     ax.set_axis_off()
#     123     plt.draw_if_interactive()
#
# /usr/local/lib/python3.7/dist-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     329
#     330     if pos is None:
# --> 331         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     332
#     333     draw_networkx_nodes(G, pos, **node_kwds)
#
# /usr/local/lib/python3.7/dist-packages/networkx/utils/decorators.py in argmap_spring_layout_10(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       5 import warnings
#       6
#
# /usr/local/lib/python3.7/dist-packages/networkx/drawing/layout.py in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     480             k = dom_size / np.sqrt(nnodes)
#     481         pos = _sparse_fruchterman_reingold(
# --> 482             A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     483         )
#     484     except ValueError:
#
# /usr/local/lib/python3.7/dist-packages/networkx/utils/decorators.py in func(_argmap__wrapper, *args, **kwargs)
#     793
#     794             def func(*args, __wrapper=None, **kwargs):
# --> 795                 return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#     796
#     797         # standard function-wrapping stuff
#
# /usr/local/lib/python3.7/dist-packages/networkx/utils/decorators.py in argmap__sparse_fruchterman_reingold_18(A, k, pos, fixed, iterations, threshold, dim, seed)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       5 import warnings
#       6
#
# /usr/local/lib/python3.7/dist-packages/networkx/drawing/layout.py in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     623             # displacement "force"
#     624             displacement[:, i] += (
# --> 625                 delta * (k * k / distance ** 2 - Ai * distance / k)
#     626             ).sum(axis=1)
#     627         # update positions
#
# KeyboardInterrupt:

# %%
N = 10000
m = 1
G = nx.barabasi_albert_graph(N,m)
degree_hist = nx.degree_histogram(G)
degree_prob = np.array(degree_hist)/G.number_of_nodes()
plt.bar(np.arange(len(degree_hist)),degree_prob)
# Out:
# <BarContainer object of 347 artists>

# %%
#nx.draw(G)

# %%
G = nx.read_weighted_edgelist("/content/DatasetsComplexNetworksCourse/eco-stmarks.edges")
nx.draw(G)

# %%
G2 = nx.read_weighted_edgelist("/content/CN1/opencell-protein-interactions_inter_stoich.csv")
nx.draw(G2)

# %%
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G,pos,node_size=20)
nx.draw_networkx_edges(G,pos,alpha=0.1)
